# %% [markdown]
# ## GRIP - The Sparks Foundation
# ## Data Science & Busniess Analytics
# ## Author: Dhaval Mendapara
# ## Task 1: Prediction using supervised ML

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Data

# %%
data = pd.read_csv('http://bit.ly/w-data')
data
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
data.shape
# Out:
# (25, 2)

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
x=data["Hours"]
y=data["Scores"]

# %%
plt.figure(figsize=(10,8))
plt.scatter(x,y)
plt.xlabel("Houres")
plt.ylabel("Score")
plt.title("Scores vs Hours")
plt.show()

# %% [markdown]
# ### Creating Model

# %%
xf=np.array(data[["Hours"]])
yf=np.array(data[["Scores"]])

# %%
x_train, x_test, y_train , y_test= train_test_split(xf,yf, test_size=0.2)

# %%
regr=linear_model.LinearRegression(normalize=True)
regr.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=True)

# %%
y_pred=regr.predict(x_test)

# %%
regr_line=regr.coef_*x_train +regr.intercept_
plt.figure(figsize=(10,8))
plt.scatter(x_test, y_test)
plt.plot(x_train, regr_line)
plt.show()

# %% [markdown]
# ### Prediction with Model

# %%
pred=regr.predict([[9.25]])
print('Score for 9.25 hrs study is: ', pred[0])
# Out:
# Score for 9.25 hrs study is:  [93.22562237]

# %%
print('R2_SCORE IS:', r2_score(y_test,y_pred))
print('Mean_squared_error is: ', mean_squared_error(y_test,y_pred))
# Out:
# R2_SCORE IS: 0.9259137930920227
# Mean_squared_error is:  25.349336555633503
